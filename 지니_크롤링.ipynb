# %% [markdown]
# <a href="https://colab.research.google.com/github/jimyoung98/Crawling/blob/master/%EC%A7%80%EB%8B%88_%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 지니 차트 200위 까지 크롤링
# 반복문을 사용하여 크롤링
# 수집한 데이터를 데이터프레임으로 만들고
# 엑셀로 출력
# 과제는 깃허브에 제출
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
     
data = []
num = 1
for j in range(1,5):
  site = f'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230601&hh=13&rtm=Y&pg={j}'
  header = {"User-Agent":
  "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
  request = requests.get(site, headers=header)
  soup = bs(request.text)

  tds = soup.findAll('td', {'class':'info'})
  for i in range(len(tds)): 
    title = tds[i].find('a', {'class':'title ellipsis'}).text.strip()
    artist = tds[i].find('a', {'class':'artist ellipsis'}).text.strip()
    print('{0:3d}위 {1} - {2}'.format(num, title, artist))
    dic = {'순위':num, '타이틀':title, '가수':artist}
    data.append(dic)
    num += 1
df = pd.DataFrame(data)
df.to_excel('genie_music.xlsx')
# Out:
#   1위 퀸카 (Queencard) - (여자)아이들
#   2위 I AM - IVE (아이브)
#   3위 Spicy - aespa
#   4위 Kitsch - IVE (아이브)
#   5위 UNFORGIVEN (Feat. Nile Rodgers) - LE SSERAFIM (르세라핌)
#   6위 꽃 - 지수 (JISOO)
#   7위 Hype boy - NewJeans
#   8위 Ditto - NewJeans
#   9위 손오공 - 세븐틴 (SEVENTEEN)
#  10위 사건의 지평선 - 윤하 (YOUNHA)
#  11위 사랑은 늘 도망가 - 임영웅
#  12위 Cupid - FIFTY FIFTY
#  13위 심 (心) - DK (디셈버)
#  14위 I Don't Think That I Like Her - Charlie Puth
#  15위 Teddy Bear - STAYC (스테이씨)
#  16위 우리들의 블루스 - 임영웅
#  17위 After LIKE - IVE (아이브)
#  18위 파이팅 해야지 (Feat. 이영지) - 부석순 (SEVENTEEN)
#  19위 London Boy - 임영웅
#  20위 이제 나만 믿어요 - 임영웅
#  21위 다시 만날 수 있을까 - 임영웅
#  22위 OMG - NewJeans
#  23위 Dangerously - Charlie Puth
#  24위 Polaroid - 임영웅
#  25위 무지개 - 임영웅
#  26위 LOVE DIVE - IVE (아이브)
#  27위 CHRISTIAN - Zior Park
#  28위 Attention - NewJeans
#  29위 헤어지자 말해요 - 박재정
#  30위 아버지 - 임영웅
#  31위 이브, 프시케 그리고 푸른 수염의 아내 - LE SSERAFIM (르세라핌)
#  32위 A bientot - 임영웅
#  33위 사랑해 진짜 - 임영웅
#  34위 ANTIFRAGILE - LE SSERAFIM (르세라핌)
#  35위 손이 참 곱던 그대 - 임영웅
# ...
